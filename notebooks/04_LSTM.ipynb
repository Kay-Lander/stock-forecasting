# %%
import os
os.chdir(r'C:\Users\sande\Code\Personal\Python\DataScience\Project_3')


import sys
sys.path.append('..')
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from src.data_loader import fetch_ticker, TICKERS
from src.evaluate import compute_metrics, plot_predictions
import warnings
warnings.filterwarnings('ignore')
 
# Reproducibility
tf.random.set_seed(42)
np.random.seed(42)
 
SEQUENCE_LENGTH = 60   # use 60 days of history to predict next day
all_results = []
 
 
def create_sequences(data, seq_length):
    '''Convert price array into (X, y) sequences for LSTM.'''
    X, y = [], []
    for i in range(seq_length, len(data)):
        X.append(data[i-seq_length:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)
 
 
for ticker in TICKERS:
    print(f'\n{'='*50}')
    print(f'Training LSTM on {ticker}...')
    print(f'{'='*50}')
 
    df = fetch_ticker(ticker)
    prices = df[['Close']].values
 
    # Scale to 0-1 range — LSTM trains better on normalized data
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(prices)
 
    # Train/test split — 80/20 chronological
    split  = int(len(scaled) * 0.80)
    train  = scaled[:split]
    test   = scaled[split - SEQUENCE_LENGTH:]   # include lookback window
 
    # Create sequences
    X_train, y_train = create_sequences(train, SEQUENCE_LENGTH)
    X_test,  y_test  = create_sequences(test,  SEQUENCE_LENGTH)
 
    # Reshape for LSTM: (samples, timesteps, features)
    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test  = X_test.reshape(X_test.shape[0],   X_test.shape[1],  1)
 
    # Build LSTM model
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(SEQUENCE_LENGTH, 1)),
        Dropout(0.2),
        LSTM(32, return_sequences=False),
        Dropout(0.2),
        Dense(16, activation='relu'),
        Dense(1)
    ])
 
    model.compile(optimizer='adam', loss='mean_squared_error')
 
    # Early stopping prevents overfitting
    early_stop = EarlyStopping(
        monitor='val_loss', patience=10,
        restore_best_weights=True
    )
 
    # Train
    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=32,
        validation_split=0.1,
        callbacks=[early_stop],
        verbose=1
    )
 
    # Predict and inverse transform back to real prices
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler.inverse_transform(y_pred_scaled).flatten()
    y_true = scaler.inverse_transform(y_test.reshape(-1,1)).flatten()
 
    # Get test dates
    test_dates = df.index[split:]
 
    # Evaluate
    metrics = compute_metrics(y_true, y_pred, 'LSTM', ticker)
    all_results.append(metrics)
 
    # Plot predictions
    plot_predictions(test_dates, y_true, y_pred, 'LSTM', ticker)
 
    # Plot training loss curve
    plt.figure(figsize=(10, 4))
    plt.plot(history.history['loss'],     label='Train Loss', color='#1B3A6B')
    plt.plot(history.history['val_loss'], label='Val Loss',   color='#C45C00')
    plt.title(f'LSTM Training Loss — {ticker}', fontweight='bold')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'outputs/figures/lstm_loss_{ticker}.png', dpi=150)
    plt.show()
 
# Save all results
pd.DataFrame(all_results).to_csv('outputs/results/lstm_results.csv', index=False)
print('\nLSTM complete. All results saved.')
# Out:
# ...
# Training LSTM on AAPL...
# ...
# AAPL: loaded from cache (1883 rows)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.0178 - val_loss: 0.0194
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0018 - val_loss: 0.0050
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0017 - val_loss: 0.0048
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0015 - val_loss: 0.0078
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0014 - val_loss: 0.0060
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0013 - val_loss: 0.0040
# ...

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                        │ (None, 60, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 60, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_9 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 32)                  │               0 │
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
# Load all results
prophet = pd.read_csv('outputs/results/prophet_results.csv')
xgb     = pd.read_csv('outputs/results/xgboost_results.csv')
lstm    = pd.read_csv('outputs/results/lstm_results.csv')
 
all_results = pd.concat([prophet, xgb, lstm])
 
# Pivot for clean comparison table
comparison = all_results.pivot_table(
    index='ticker', columns='model',
    values=['rmse','mae','dir_acc']
).round(2)
 
print('\n===== FINAL MODEL COMPARISON =====')
print(comparison.to_string())
comparison.to_csv('outputs/results/final_comparison.csv')
 
# Bar chart — Directional Accuracy by model and ticker
dir_acc = all_results.pivot(index='ticker', columns='model', values='dir_acc')
dir_acc.plot(kind='bar', figsize=(12, 5), color=['#1B3A6B','#2E75B6','#C45C00'])
plt.title('Directional Accuracy by Model and Ticker (%)', fontweight='bold', fontsize=13)
plt.ylabel('Directional Accuracy (%)')
plt.axhline(50, color='red', linestyle='--', label='Random Baseline (50%)')
plt.legend()
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('outputs/figures/final_comparison.png', dpi=150)
plt.show()
# Out:
# ===== FINAL MODEL COMPARISON =====
#        dir_acc                    mae                   rmse
# model     LSTM Prophet XGBoost   LSTM Prophet XGBoost   LSTM Prophet XGBoost
# ticker
# AAPL      46.5    41.9    53.3  15.02   20.60   15.91  17.60   25.47   22.02
# AMZN      53.7    45.2    45.4   7.29   22.93   10.55   9.23   24.39   15.33
# GOOGL     54.0    58.1    49.5  16.90   42.20   70.75  22.73   52.31   97.52
# MSFT      53.2    45.2    47.8  10.71   91.55   29.26  13.82   93.23   39.28
# TSLA      49.2    59.7    46.7  28.34   41.80   16.62  32.18   48.12   21.43
